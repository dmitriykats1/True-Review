# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.cloud import bigquery
import matplotlib
matplotlib.rcParams['figure.figsize'] = (14, 8)

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 100)
pd.set_option('display.max_info_columns', 200)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/dmitriykats/Documents/SpringBoard/Springboard/flight_key.json"

# %%
bigquery_client = bigquery.Client()

# %% [markdown]
# # Non Fast Food Restaurants

# %%
QUERY_rest = '''

SELECT * FROM `nodal-reserve-227121.Yelp.yelp_business` 
WHERE categories LIKE '%Rest%' 
AND categories NOT LIKE '%Fast%'
AND address NOT LIKE '%Airport%'

'''
query_job_rest = bigquery_client.query(QUERY_rest)

# %%
df_rest = query_job_rest.to_dataframe()
df_rest.describe()
# Out:
#            latitude     longitude         stars  review_count       is_open
# count  48588.000000  48588.000000  48588.000000  48588.000000  48588.000000
# mean      40.478215    -84.605253      3.538168     63.111633      0.720260
# std        5.605004     28.279144      0.747268    158.413548      0.448876
# min      -34.515952   -142.466650      1.000000      3.000000      0.000000
# 25%       35.409456   -111.923578      3.000000      7.000000      0.000000
# 50%       41.424868    -80.713966      3.500000     19.000000      1.000000
# 75%       43.746822    -79.382915      4.000000     59.000000      1.000000
# max       89.999314    115.086769      5.000000   7361.000000      1.000000

# %% [markdown]
# # Fast Food Restaurants

# %%
QUERY_fast = '''

SELECT * FROM `nodal-reserve-227121.Yelp.yelp_business` 
WHERE categories LIKE '%Rest%' 
AND categories LIKE '%Fast%'
AND address NOT LIKE '%Airport%'

'''
query_job_fast = bigquery_client.query(QUERY_fast)

# %%
df_fast = query_job_fast.to_dataframe()
df_fast.head(50)
# Out:
#                business_id                                               name    neighborhood  \
# 0   cK2JaWuMM84fYjtrPFfvNQ                                              "KFC"        New Town
# 1   irCBE0vRZ9oQZ26qMR-5HA                                    "Amaya Express"      Unionville
# 2   Le83s2lLwX3wj5W2Mam60Q  "Hero Certified Burgers - Jane & Major Mackenzie"            None
# 3   evWd8FifWdKDuDXzMcaasw                                           "Subway"   Downtown Core
# 4   sro9D0YFB-FJyRVLQls1QA                                        "Taco Bell"            None
# 5   WynSwONQjN7heBpTtP2Csw                           "Chipotle Mexican Grill"            None
# 6   C1gj-EqhSZ1BcCejDyV-fQ                                            "Sonic"            None
# 7   qrcAGkBi0Qhg0HIfUJBDhg                                      "Burger King"            None
# 8   e2IqS9_G0Hpulw5ItU-Y9Q                                       "McDonald's"            None
# 9   BPWZRoeUQaKg5jAqLGkbMw                                       "McDonald's"       Homestead
# 10  nxAo0oDgsNlduzUuuUL4Fg                                   "Steak 'n Shake"       Homestead
# 11  4t8o25f4-fCt3cVzzNM1-w                               "Long John Silver's"            None
# 12  UvfBeHic40rwnxFBvfAP5A                                              "KFC"            None
# 13  Sg3qj0mhSEYX4Co3fVHHwQ                                       "McDonald's"            None
# 14  EUgHFeAvock2Ut3iWPlG8Q                                        "Taco Bell"            None
# 15  ScXWzVisOI4P-g-LoDTaiA                                           "Subway"            None
# 16  ax8kuBZVtC0_eCn_rN_-6A                                      "Burger King"      South Side
# 17  9Lu2VvdAPswV-RRiQFfXXQ                                   "Steak 'n Shake"            None
# 18  Prd8JRVvPvL2d32GgtNCwQ                               "Long John Silver's"         Carrick
# 19  _rKz-rQPzUAIZWlUHCKgow                                       "McDonald's"         Oakland
# 20  6dDItJbFIwYCmoLZF3iTcg                        "Popeyes Louisiana Kitchen"         Oakland
# 21  ECXHwaJW7Lc7qDlH89Syaw                                           "Arby's"      Banksville
# 22  Uc2PqdAPWPMxe6_YHB4wHQ                                          "Wendy's"            None
# 23  S_VoH2qPxjm5l3MeuCgunw                                        "Taco Bell"            None
# 24  HNbX93hyrua2p6LO4IwdHA                                        "Taco Bell"            None
# 25  NaqR4ptSaeqm33-rAtBz0w                                          "Wendy's"    Point Breeze
# 26  1fMXFNFwZEtTy9p8sEmiNw                                        "Taco Bell"            None
# 27  mVbGnu5VsAG79b0fMoKItA                                       "McDonald's"  Strip District
# 28  iDuwJjTE5Sw_bb3aFSTBCg                                           "Subway"        Downtown
# 29  Y-vxPbvPKcaLiYa9ZBXoDg                                       "McDonald's"        Downtown
# 30  wZEK7GmLJ3hmkYBiRCo4Qw                                           "Subway"            None
# 31  rzByiKaj-bLeLz-zKNBQdg                                      "Dairy Queen"       Overbrook
# 32  hZ79bbzGuiU0ThbasNEALQ                                       "McDonald's"            None
# 33  jf_N8zWp30usaMLXdJs9Jg                                          "Wendy's"            None
# 34  OOThzIpIiCRok8zaN0NPwQ                                           "Subway"       Shadyside
# 35  VveJgvCshJios_o-zwKJIw                                        "Taco Bell"      North Side
# 36  CP7TRCpeBr1sTtWqcfRHxQ                                       "McDonald's"            None
# 37  2cfzQGANxuIGcCUrlwnV7w                        "Popeyes Louisiana Kitchen"            None
# 38  V4NwBv9O6DWTl36ZKZrfpw                                          "Wendy's"            None
# 39  YYEm5MR6HMCQYI0k1wVnXA                                          "Wendy's"            None
# 40  BoTb3FqOsJaFe_koVfyGbw                           "Chipotle Mexican Grill"            None
# 41  LX2tNHlYsxHNdNo5j0ZF7A                                   "Steak 'n Shake"            None
# 42  gB7X5o33o6W_rAGgHunSCA                                       "McDonald's"            None
# 43  RBwAfKwvWcZ8NY7zKbzYHg                                          "Wendy's"            None
# 44  7svK0DI4BOP0cqjSww7cZQ                                       "McDonald's"            None
# 45  GaP5KfdlDuNasKgTNR8Saw                                          "Wendy's"            None
# 46  leG7stzwTdc37b8Ma1TEeA                                       "McDonald's"            None
# 47  78jHxNL8wHMSq_j8KF9exA                                           "Subway"            None
# 48  qbCPF1Z-Dher2MYUYFCX4Q                                       "McDonald's"            None
# 49  -y3OEfG-Glha0qp2iWlxoA                                          "Wendy's"            None
#
#                         address            city state postal_code   latitude  longitude  stars  \
# 0     "7 S Saint Andrew Street"       Edinburgh   EDH         EH2  55.953374  -3.191350    2.0
# 1            "5000 Highway 7 E"         Markham    ON         L3R  43.865789 -79.291420    2.0
# 27            11        1             Restaurants;Fast Food;Hot Dogs;Burgers
# 28             3        1                   Sandwiches;Restaurants;Fast Food
# 29            14        1             Restaurants;Fast Food;Burgers;Hot Dogs
# 30             4        1                   Restaurants;Fast Food;Sandwiches
# 31            17        1  Food;Restaurants;Ice Cream & Frozen Yogurt;Fas...
# 32             6        1                      Burgers;Fast Food;Restaurants
# 33             9        1                      Fast Food;Restaurants;Burgers
# 34             5        1                   Fast Food;Sandwiches;Restaurants
# 35             5        1              Tex-Mex;Fast Food;Restaurants;Mexican
# 36             4        1                      Fast Food;Restaurants;Burgers
# 37            18        1       Fast Food;Chicken Wings;Southern;Restaurants
# 38             8        1                      Fast Food;Burgers;Restaurants
# 39             5        1                      Fast Food;Restaurants;Burgers
# 40            34        1                      Restaurants;Fast Food;Mexican
# 41            27        1  American (New);Sandwiches;Restaurants;Fast Foo...
# 42             4        1                      Fast Food;Burgers;Restaurants
# 43            10        1             Fast Food;Hot Dogs;Restaurants;Burgers
# 44             3        1                      Restaurants;Fast Food;Burgers
# 45             8        1                      Fast Food;Restaurants;Burgers
# 46             7        1                      Burgers;Fast Food;Restaurants
# 47             5        1                   Sandwiches;Fast Food;Restaurants
# 48            19        1                      Burgers;Fast Food;Restaurants
# 49            15        1                      Fast Food;Burgers;Restaurants

# %%
df_fast.describe()
# Out:
#           latitude    longitude        stars  review_count      is_open
# count  6260.000000  6260.000000  6260.000000   6260.000000  6260.000000
# mean     38.876913   -90.401783     2.882428     24.918850     0.901278
# std       5.765185    28.514315     0.915068     48.239896     0.298312
# min     -34.509972  -115.350086     1.000000      3.000000     0.000000
# 25%      33.640892  -112.135999     2.000000      5.000000     1.000000
# 50%      36.158880   -82.145151     3.000000     11.000000     1.000000
# 75%      43.575796   -79.717358     3.500000     25.000000     1.000000
# max      59.422170    10.685297     5.000000    987.000000     1.000000

# %%
df_fast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6260 entries, 0 to 6259
# Data columns (total 13 columns):
# business_id     6260 non-null object
# name            6260 non-null object
# neighborhood    2223 non-null object
# address         6260 non-null object
# city            6260 non-null object
# state           6260 non-null object
# postal_code     6255 non-null object
# latitude        6260 non-null float64
# longitude       6260 non-null float64
# stars           6260 non-null float64
# review_count    6260 non-null int64
# is_open         6260 non-null int64
# categories      6260 non-null object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 635.9+ KB

# %% [markdown]
# # Get reviews and join with non Fast Food Restaurants

# %%
QUERY_rev = '''

SELECT 
r.user_id, r.business_id, r.stars as rev_stars, r.date, r.text,
r.useful, r.funny, r.cool,
b.business_id as bus_id, b.name, b.neighborhood, b.address, b.city, b.state, b.postal_code, 
b.latitude, b.longitude, b.stars as bus_stars, b.review_count, b.is_open, b.categories

FROM 
`nodal-reserve-227121.Yelp.yelp_reviews` r

LEFT JOIN
`nodal-reserve-227121.Yelp.yelp_business` b

ON
r.business_id = b.business_id

WHERE b.categories LIKE '%Rest%' 
AND b.categories NOT LIKE '%Fast%'
AND b.address NOT LIKE '%Airport%'

'''
query_job_rev = bigquery_client.query(QUERY_rev)

# %%
df_reviews = query_job_rev.to_dataframe()

# %%
df_reviews.head()
# Out:
#                   user_id             business_id  rev_stars        date  \
# 0  DUfWxxewcJgGcc1Y189XSQ  ZcAoKSDT6BNcWsn3o4-WVA          2  2017-01-07
# 1  oAJf-_URH4QBMs2ZMpjUyA  9VhZRkmyoEho58vmnMh_Hg          3  2016-04-11
# 2  SOb8RgcqBGbwlq9LZXy3fQ  IgOaTag1zhIXndxngP0M3w          1  2016-09-21
# 3  Iwe-xN6dnugdZ0KiQjO6Hg  Fvd8qeJCXFbMYQk45S7iBQ          5  2014-06-30
# 4  VSCpdfEtjdWjTbBVKMb5eA  mF2EW3twSrFPmT_RVV1-Qg          2  2011-11-18
#
#                                                 text  useful  funny  cool                  bus_id  \
# 0  Cool place packed to the rafters. Menu is pret...       1      0     0  ZcAoKSDT6BNcWsn3o4-WVA
# 1  I've had mixed experiences at this Montana's, ...       0      0     0  9VhZRkmyoEho58vmnMh_Hg
# 2  Die Angaben hier sind leider nicht mehr ganz k...       0      0     0  IgOaTag1zhIXndxngP0M3w
# 3  My family came in while waiting for our time a...       0      0     0  Fvd8qeJCXFbMYQk45S7iBQ
# 4  I would not recommend this place for Chinese f...       3      5     0  mF2EW3twSrFPmT_RVV1-Qg
#
#                           name neighborhood                    address           city state  \
# 0                 "Me & Julio"         None  "2784 S Fish Hatchery Rd"      Fitchburg    WI
# 1        "Montana's BBQ & Bar"         None            "8735 Yonge St"  Richmond Hill    ON
# 2         "Restaurant Ganesha"         None          "Auberlenstr. 40"       Fellbach    BW
# 3  "Las Fuentes Mexican Grill"         None    "13621 N Litchfield Rd"       Surprise    AZ
# 4             "House of Hunan"         None             "18 Public Sq"         Medina    OH
#
#   postal_code   latitude   longitude  bus_stars  review_count  is_open  \
# 0       53711  43.005728  -89.427154        3.0           102        1
# 1     L4C 6Z1  43.840823  -79.428224        3.0            49        1
# 2       70736  48.818648    9.270925        3.0             8        1
# 3       85374  33.607472 -112.355941        3.5           151        1
# 4       44256  41.138544  -81.864299        3.0            83        1
#
#                                           categories
# 0  Restaurants;Mexican;Tex-Mex;American (Traditio...
# 1  Comfort Food;Restaurants;American (Traditional...
# 2                                 Restaurants;Indian
# 3                                Mexican;Restaurants
# 4                                Restaurants;Chinese

# %%
df_reviews.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3066833 entries, 0 to 8208
# Data columns (total 21 columns):
# user_id         object
# business_id     object
# rev_stars       int64
# date            object
# text            object
# useful          int64
# funny           int64
# cool            int64
# bus_id          object
# name            object
# neighborhood    object
# address         object
# city            object
# state           object
# postal_code     object
# latitude        float64
# longitude       float64
# bus_stars       float64
# review_count    int64
# is_open         int64
# categories      object
# dtypes: float64(3), int64(6), object(12)
# memory usage: 4.3 GB

# %%
df_reviews.to_csv('./Data/All.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # EDA

# %%
df_reviews = pd.read_csv('./Data/All.csv')

# %%
df_reviews['text length'] = df_reviews['text'].apply(len)
df_reviews.head()
# Out:
#                   user_id             business_id  rev_stars        date  \
# 0  DUfWxxewcJgGcc1Y189XSQ  ZcAoKSDT6BNcWsn3o4-WVA          2  2017-01-07
# 1  oAJf-_URH4QBMs2ZMpjUyA  9VhZRkmyoEho58vmnMh_Hg          3  2016-04-11
# 2  SOb8RgcqBGbwlq9LZXy3fQ  IgOaTag1zhIXndxngP0M3w          1  2016-09-21
# 3  Iwe-xN6dnugdZ0KiQjO6Hg  Fvd8qeJCXFbMYQk45S7iBQ          5  2014-06-30
# 4  VSCpdfEtjdWjTbBVKMb5eA  mF2EW3twSrFPmT_RVV1-Qg          2  2011-11-18
#
#                                                 text  useful  funny  cool                  bus_id  \
# 0  Cool place packed to the rafters. Menu is pret...       1      0     0  ZcAoKSDT6BNcWsn3o4-WVA
# 1  I've had mixed experiences at this Montana's, ...       0      0     0  9VhZRkmyoEho58vmnMh_Hg
# 2  Die Angaben hier sind leider nicht mehr ganz k...       0      0     0  IgOaTag1zhIXndxngP0M3w
# 3  My family came in while waiting for our time a...       0      0     0  Fvd8qeJCXFbMYQk45S7iBQ
# 4  I would not recommend this place for Chinese f...       3      5     0  mF2EW3twSrFPmT_RVV1-Qg
#
#                           name neighborhood                    address           city state  \
# 0                 "Me & Julio"         None  "2784 S Fish Hatchery Rd"      Fitchburg    WI
# 1        "Montana's BBQ & Bar"         None            "8735 Yonge St"  Richmond Hill    ON
# 2         "Restaurant Ganesha"         None          "Auberlenstr. 40"       Fellbach    BW
# 3  "Las Fuentes Mexican Grill"         None    "13621 N Litchfield Rd"       Surprise    AZ
# 4             "House of Hunan"         None             "18 Public Sq"         Medina    OH
#
#   postal_code   latitude   longitude  bus_stars  review_count  is_open  \
# 0       53711  43.005728  -89.427154        3.0           102        1
# 1     L4C 6Z1  43.840823  -79.428224        3.0            49        1
# 2       70736  48.818648    9.270925        3.0             8        1
# 3       85374  33.607472 -112.355941        3.5           151        1
# 4       44256  41.138544  -81.864299        3.0            83        1
#
#                                           categories  text length
# 0  Restaurants;Mexican;Tex-Mex;American (Traditio...          369
# 1  Comfort Food;Restaurants;American (Traditional...          524
# 2                                 Restaurants;Indian          125
# 3                                Mexican;Restaurants          256
# 4                                Restaurants;Chinese          992

# %%
g = sns.FacetGrid(data=df_reviews, col='rev_stars')
g.map(plt.hist, 'text length', bins=50)

# %%
sns.boxplot(x='rev_stars', y='text length', data=df_reviews)

# %%
sns.distplot(df_reviews.city)

# %%
df_reviews.groupby(['city']).size().sort_values(ascending=False)[0:10]

# %%
#EDA Ideas
#map plot of where users are from(might not be available) compared to each city, locals vs tourists ...could be a bubble plot

#breakdown of restaurants by type for the area as a function of reviews, and then review histograms 
#per type of restaurant
#Need to figure out how to break out restaurant type from the categories column

#might have to get rid of foreign language reviews

#focus on one or few large cities

#get rid of low word count reviews? and high count reviews?
